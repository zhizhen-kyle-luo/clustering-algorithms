# %%
from tqdm.notebook import tqdm as progress
import pandas as pd
import plotly.express as px
from plotly.offline import plot
import dimcli
from dimcli.utils import *
import os, sys, time, json
from IPython.display import Image
from IPython.core.display import HTML

# %%
#Log into Dimensions
#API key is: 9F8D648F0D7E437CB1736BEBDF007F02
#!pip install dimcli -U --quiet 

print("==\nLogging in..")
# https://digital-science.github.io/dimcli/getting-started.html#authentication
ENDPOINT = "https://app.dimensions.ai"
if 'google.colab' in sys.modules:
    import getpass
    KEY = getpass.getpass(prompt='API Key: ')  
    dimcli.login(key=KEY, endpoint=ENDPOINT)
else:
    KEY = "9F8D648F0D7E437CB1736BEBDF007F02"
    dimcli.login(key=KEY, endpoint=ENDPOINT)
dsl = dimcli.Dsl()
# Out:
# ==
# Logging in..
# Dimcli - Dimensions API Client (v1.1)
# Connected to: <https://app.dimensions.ai/api/dsl> - DSL v2.8
# Method: manual login

# %%
search_Var = "[associated_grant_ids+associated_publication+associated_publication_id+authors+category_bra+category_for+category_for_2020+category_hra+category_hrcs_hc+category_hrcs_rac+category_icrp_cso+category_icrp_ct+category_rcdc+category_sdg+date+date_created+date_embargo+date_inserted+date_modified+description+dimensions_url+doi+figshare_url+funder_countries+funders+id+journal+keywords+language_desc+language_title+license_name+license_url+repository+repository+research_org_cities+research_org_countries+research_org_states+research_orgs+researchers+score+title+year]"

# %%
def researcherIds(name):
    res = dsl.query_iterative(f"""search researchers for "{name}" return researchers""")
    listDict = res.json['researchers']
    allIds = set()
    for idv in listDict:
        allIds.add(idv['id'])

    allIds = list(allIds)  # Convert set back to a list if needed
    print(f'Total of {len(allIds)} unique ids for {name}: ')
    print(allIds)

    if len(allIds) > 500:
        batched_ids = [allIds[i:i+500] for i in range(0, len(allIds), 500)]
        allWorkingIDs = set()
        
        for batch in batched_ids:
            query_ids = ', '.join([f'"{id_val}"' for id_val in batch])
            query = f'search researchers where id in [{query_ids}] return researchers[id+obsolete+redirect]'
            
            res2 = dsl.query_iterative(query)
            listDict2 = res2.json['researchers']
            
            for person in listDict2:
                if person['obsolete'] == 0:  # Current Working Id(s)
                    allWorkingIDs.add(person["id"])
                else:
                    for ids in person['redirect']:
                        allWorkingIDs.add(ids)
        
        print(f'++++++++ FINAL {len(allWorkingIDs)} Working ID(s) +++++++++++')  
        print(allWorkingIDs)
        
    else:
        query_ids = ', '.join([f'"{id_val}"' for id_val in allIds])
        query = f'search researchers where id in [{query_ids}] return researchers[id+obsolete+redirect]'
        
        res2 = dsl.query_iterative(query)
        listDict2 = res2.json['researchers']
        allWorkingIDs = set()
        
        for person in listDict2:
            if person['obsolete'] == 0:  # Current Working Id(s)
                allWorkingIDs.add(person["id"])
            else:
                for ids in person['redirect']:
                    allWorkingIDs.add(ids)
        
        print(f'++++++++ FINAL {len(allWorkingIDs)} Working ID(s) +++++++++++')  
        print(allWorkingIDs)

    
    return allWorkingIDs
#testIDs = researcherIds("MICHAEL AGUS")
#Gareth L Nealon
testIDs = researcherIds("Gareth Nealon")
# Out:
# Starting iteration with limit=1000 skip=0 ...
# 0-3 / 3 (0.42s)
# ===
# Records extracted: 3
# Starting iteration with limit=1000 skip=0 ...
# Total of 3 unique ids for Gareth Nealon:
# ['ur.01146047701.41', 'ur.016071434137.11', 'ur.015007635567.03']
# 0-3 / 3 (0.37s)
# ===
# Records extracted: 3
# ++++++++ FINAL 1 Working ID(s) +++++++++++
# {'ur.01146047701.41'}

# %%
#using researcher name to find datasets
def findingDatasets(name):
    all_datasets = {}
    res = dsl.query_iterative(f"""search datasets where authors = "{name}" return datasets{search_Var}""")
    number = res.json['_stats']['total_count']
    typeDict = {}
    print(f'{name} has {number} datasets')
    
    listDict = res.json['datasets']
    all_datasets[name] = listDict
        
    return all_datasets
        
findingDatasets("Simone Vigod")
# Out:
# Starting iteration with limit=1000 skip=0 ...
# 0-8 / 8 (0.48s)
# ===
# Records extracted: 8
# Simone Vigod has 8 datasets
# {'Simone Vigod': [{'associated_publication': {'doi': '10.1371/journal.pone.0284389',
#     'id': 'pub.1157499910',
#     'pmcid': 'PMC10132527',
#     'pmid': '37099524'},
#    'associated_publication_id': 'pub.1157499910',
#    'authors': [{'name': 'Orges Alabaku'},
#     {'name': 'Alyssa Yang'},
#     {'name': 'Shenthuraan Tharmarajah'},
#     {'name': 'Katie Suda'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Mina Tadrous'}],
#    'category_for': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80232', 'name': '5202 Biological Psychology'},
#     {'id': '80057', 'name': '3214 Pharmacology and Pharmaceutical Sciences'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80023', 'name': '52 Psychology'}],
#    'category_for_2020': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80232', 'name': '5202 Biological Psychology'},
#     {'id': '80057', 'name': '3214 Pharmacology and Pharmaceutical Sciences'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80023', 'name': '52 Psychology'}],
#    'category_hrcs_hc': [{'id': '890', 'name': 'Generic health relevance'}],
#    'category_rcdc': [{'id': '380', 'name': 'Mental Health'}],
#    'date': '2023-04-26',
#    'date_created': '2023-04-26',
#    'date_inserted': '2023-05-04',
#    'date_modified': '2023-06-21',
#    'description': 'Linear regression analyses of percent change in use for atypical antipsychotics, antidepressants, and benzodiazepines using a country economic status and baseline rate of use per drug class as predictors.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.94351161',
#    'doi': '10.1371/journal.pone.0284389.t001',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Linear_regression_analyses_of_percent_change_in_use_for_atypical_antipsychotics_antidepressants_and_benzodiazepines_using_a_country_economic_status_and_baseline_rate_of_use_per_drug_class_as_predictors_/22702045',
#    'id': 'dataset.94351161',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['treatment utilization increasing',
#     'treatment utilization compared',
#     'linear regression analyses',
#     'average percent changes',
#     '5 %, respectively',
#     '42 %, respectively',
#     '916 ), aap',
#     'xlink "> high',
#     'country &# 8217',
#     'average baseline rates',
#     '69 %, respectively',
#     'economic status increases',
#     'xlink ">',
#     'economic status',
#     'percent change',
#     'baseline rate',
#     '23 ),',
#     'use increases',
#     'standard units',
#     'series analysis',
#     'sectional time',
#     'sectional analysis',
#     'july 2019',
#     'july 2014',
#     'higher rate',
#     'found demonstrating',
#     'controlled rates',
#     'atypical antipsychotic',
#     'aaps increases',
#     'aaps ),'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '5206379', 'name': 'Pittsburgh'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '5206379', 'name': 'Pittsburgh'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'US', 'name': 'United States'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'US', 'name': 'United States'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'US-PA', 'name': 'Pennsylvania'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'US-PA', 'name': 'Pennsylvania'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Pittsburgh',
#      'country_code': 'US',
#      'country_name': 'United States',
#      'id': 'grid.21925.3d',
#      'latitude': 40.443504,
#      'linkout': ['http://www.pitt.edu/'],
#      'longitude': -79.961525,
#      'name': 'University of Pittsburgh',
#      'state_name': 'Pennsylvania',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'acronym': 'VAPHS',
#      'city_name': 'Pittsburgh',
#      'country_code': 'US',
#      'country_name': 'United States',
#      'id': 'grid.413935.9',
#      'latitude': 40.495415,
#      'linkout': ['http://www.pittsburgh.va.gov/'],
#      'longitude': -79.88787,
#      'name': 'VA Pittsburgh Healthcare System',
#      'state_name': 'Pennsylvania',
#      'types': ['Healthcare']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'acronym': 'ICES',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.418647.8',
#      'latitude': 43.723167,
#      'linkout': ['http://www.ices.on.ca/'],
#      'longitude': -79.372536,
#      'name': 'Institute for Clinical Evaluative Sciences',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'researchers': [{'first_name': 'Orges',
#      'id': 'ur.016363607165.32',
#      'last_name': 'Alabaku',
#      'research_orgs': ['grid.21925.3d']},
#     {'first_name': 'Shenthuraan',
#      'id': 'ur.012271704235.23',
#      'last_name': 'Tharmarajah',
#      'orcid_id': ['0000-0002-6264-1466'],
#      'research_orgs': ['grid.239585.0', 'grid.17063.33']},
#     {'first_name': 'Katie J',
#      'id': 'ur.0601042140.08',
#      'last_name': 'Suda',
#      'orcid_id': ['0000-0002-8977-1850'],
#      'research_orgs': ['grid.185648.6',
#       'grid.34477.33',
#       'grid.32224.35',
#       'grid.416738.f',
#       'grid.411461.7',
#       'grid.453225.7',
#       'grid.66875.3a',
#       'grid.240871.8',
#       'grid.89336.37',
#       'grid.21925.3d',
#       'grid.490111.c',
#       'grid.280893.8',
#       'grid.19006.3e',
#       'grid.418356.d',
#       'grid.14003.36',
#       'grid.484462.8',
#       'grid.488536.4',
#       'grid.413935.9',
#       'grid.27860.3b',
#       'grid.267301.1']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Mina',
#      'id': 'ur.01102202064.28',
#      'last_name': 'Tadrous',
#      'orcid_id': ['0000-0003-1911-6129'],
#      'research_orgs': ['grid.430617.7',
#       'grid.413555.3',
#       'grid.417199.3',
#       'grid.510849.1',
#       'grid.17091.3e',
#       'grid.231844.8',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.1013.3',
#       'grid.415502.7',
#       'grid.416544.6',
#       'grid.17063.33',
#       'grid.1003.2',
#       'grid.416553.0',
#       'grid.417293.a',
#       'grid.267301.1']}],
#    'score': 1.0,
#    'title': 'Linear regression analyses of percent change in use for atypical antipsychotics, antidepressants, and benzodiazepines using a country economic status and baseline rate of use per drug class as predictors.',
#    'year': 2023},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0229273',
#     'id': 'pub.1125058791',
#     'pmcid': 'PMC7034875',
#     'pmid': '32084192'},
#    'associated_publication_id': 'pub.1125058791',
#    'authors': [{'name': 'Bindee Kuriya'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Jin Luo'},
#     {'name': 'Jessica Widdifield'},
#     {'name': 'Nigil Haroon'}],
#    'category_bra': [{'id': '4001', 'name': 'Clinical Medicine and Science'}],
#    'category_for': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80009', 'name': '38 Economics'},
#     {'id': '80100', 'name': '3801 Applied Economics'}],
#    'category_for_2020': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80009', 'name': '38 Economics'},
#     {'id': '80100', 'name': '3801 Applied Economics'}],
#    'date': '2020-02-21',
#    'date_created': '2020-02-21',
#    'date_inserted': '2020-02-21',
#    'date_modified': '2023-06-02',
#    'description': 'Baseline characteristics of individuals with RA, AS or matched comparators who attended the emergency department for a deliberate self-harm attempt.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.7589245',
#    'doi': '10.1371/journal.pone.0229273.t001',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Baseline_characteristics_of_individuals_with_RA_AS_or_matched_comparators_who_attended_the_emergency_department_for_a_deliberate_self-harm_attempt_/11884491',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'MHLTC',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415822.8',
#      'latitude': 43.7773,
#      'linkout': ['http://www.health.gov.on.ca/en/'],
#      'longitude': -79.52799,
#      'name': 'Ministry of Health and Long Term Care',
#      'state_name': 'Ontario',
#      'types': ['Government']},
#     {'acronym': 'Arthritis Society',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.469795.0',
#      'latitude': 43.654022,
#      'linkout': ['https://arthritis.ca/'],
#      'longitude': -79.387245,
#      'name': 'Arthritis Society',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'id': 'dataset.7589245',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['health service utilization variables',
#     'RA',
#     'population-based cohort studies',
#     'crude incidence rate',
#     'HR',
#     'PY',
#     'IR',
#     'ankylosing spondylitis',
#     'DSH',
#     'population-based cohort study Objective Rheumatoid arthritis',
#     'emergency department data',
#     'self-harm',
#     'CI',
#     'comparator',
#     'AS'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'acronym': 'ICES',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.418647.8',
#      'latitude': 43.723167,
#      'linkout': ['http://www.ices.on.ca/'],
#      'longitude': -79.372536,
#      'name': 'Institute for Clinical Evaluative Sciences',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'researchers': [{'first_name': 'Bindee',
#      'id': 'ur.01222076773.99',
#      'last_name': 'Kuriya',
#      'research_orgs': ['grid.5386.8',
#       'grid.22072.35',
#       'grid.8051.c',
#       'grid.28046.38',
#       'grid.475435.4',
#       'grid.26009.3d',
#       'grid.265892.2',
#       'grid.6518.a',
#       'grid.86715.3d',
#       'grid.416193.8',
#       'grid.25073.33',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.38142.3c',
#       'grid.492573.e',
#       'grid.416448.b',
#       'grid.17063.33',
#       'grid.498791.a',
#       'grid.17089.37',
#       'grid.411439.a',
#       'grid.416166.2',
#       'grid.462844.8',
#       'grid.416167.3',
#       'grid.1010.0',
#       'grid.16872.3a',
#       'grid.63984.30',
#       'grid.21613.37']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Jin',
#      'id': 'ur.01212326461.29',
#      'last_name': 'Luo',
#      'orcid_id': ['0000-0002-9462-2016'],
#      'research_orgs': ['grid.412687.e',
#       'grid.17091.3e',
#       'grid.25073.33',
#       'grid.2515.3',
#       'grid.17063.33',
#       'grid.28046.38',
#       'grid.42327.30',
#       'grid.48336.3a',
#       'grid.56302.32',
#       'grid.416193.8',
#       'grid.418647.8',
#       'grid.65499.37',
#       'grid.415502.7',
#       'grid.14709.3b']},
#     {'first_name': 'Jessica',
#      'id': 'ur.01021574357.76',
#      'last_name': 'Widdifield',
#      'orcid_id': ['0000-0002-7464-0460'],
#      'research_orgs': ['grid.418647.8',
#       'grid.17063.33',
#       'grid.63984.30',
#       'grid.417199.3',
#       'grid.14709.3b',
#       'grid.416448.b',
#       'grid.25073.33',
#       'grid.416167.3',
#       'grid.416745.5',
#       'grid.498791.a',
#       'grid.39381.30',
#       'grid.413104.3',
#       'grid.22072.35',
#       'grid.416166.2',
#       'grid.416193.8']},
#     {'first_name': 'Nigil',
#      'id': 'ur.01344457140.05',
#      'last_name': 'Haroon',
#      'orcid_id': ['0000-0003-3210-4771'],
#      'research_orgs': ['grid.465547.1',
#       'grid.39381.30',
#       'grid.231844.8',
#       'grid.17091.3e',
#       'grid.23856.3a',
#       'grid.418905.1',
#       'grid.42327.30',
#       'grid.10776.37',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.263138.d',
#       'grid.416193.8',
#       'grid.413485.f',
#       'grid.492504.e',
#       'grid.417188.3']}],
#    'score': 1.0,
#    'title': 'Baseline characteristics of individuals with RA, AS or matched comparators who attended the emergency department for a deliberate self-harm attempt.',
#    'year': 2020},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0229273',
#     'id': 'pub.1125058791',
#     'pmcid': 'PMC7034875',
#     'pmid': '32084192'},
#    'associated_publication_id': 'pub.1125058791',
#    'authors': [{'name': 'Bindee Kuriya'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Jin Luo'},
#     {'name': 'Jessica Widdifield'},
#     {'name': 'Nigil Haroon'}],
#    'category_for': [{'id': '80021',
#      'name': '50 Philosophy and Religious Studies'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_for_2020': [{'id': '80021',
#      'name': '50 Philosophy and Religious Studies'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'date': '2020-02-21',
#    'date_created': '2020-02-21',
#    'date_inserted': '2020-02-21',
#    'date_modified': '2023-06-09',
#    'description': 'Crude incidence rates of deliberate self-harm attempt and disposition following emergency department presentations in RA, AS and matched comparators.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.7589232',
#    'doi': '10.1371/journal.pone.0229273.t002',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Crude_incidence_rates_of_deliberate_self-harm_attempt_and_disposition_following_emergency_department_presentations_in_RA_AS_and_matched_comparators_/11884494',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'MHLTC',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415822.8',
#      'latitude': 43.7773,
#      'linkout': ['http://www.health.gov.on.ca/en/'],
#      'longitude': -79.52799,
#      'name': 'Ministry of Health and Long Term Care',
#      'state_name': 'Ontario',
#      'types': ['Government']},
#     {'acronym': 'Arthritis Society',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.469795.0',
#      'latitude': 43.654022,
#      'linkout': ['https://arthritis.ca/'],
#      'longitude': -79.387245,
#      'name': 'Arthritis Society',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'id': 'dataset.7589232',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['health service utilization variables',
#     'RA',
#     'population-based cohort studies',
#     'crude incidence rate',
#     'HR',
#     'PY',
#     'IR',
#     'ankylosing spondylitis',
#     'DSH',
#     'population-based cohort study Objective Rheumatoid arthritis',
#     'emergency department data',
#     'self-harm',
#     'CI',
#     'comparator',
#     'AS'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'acronym': 'ICES',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.418647.8',
#      'latitude': 43.723167,
#      'linkout': ['http://www.ices.on.ca/'],
#      'longitude': -79.372536,
#      'name': 'Institute for Clinical Evaluative Sciences',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'researchers': [{'first_name': 'Bindee',
#      'id': 'ur.01222076773.99',
#      'last_name': 'Kuriya',
#      'research_orgs': ['grid.5386.8',
#       'grid.22072.35',
#       'grid.8051.c',
#       'grid.28046.38',
#       'grid.475435.4',
#       'grid.26009.3d',
#       'grid.265892.2',
#       'grid.6518.a',
#       'grid.86715.3d',
#       'grid.416193.8',
#       'grid.25073.33',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.38142.3c',
#       'grid.492573.e',
#       'grid.416448.b',
#       'grid.17063.33',
#       'grid.498791.a',
#       'grid.17089.37',
#       'grid.411439.a',
#       'grid.416166.2',
#       'grid.462844.8',
#       'grid.416167.3',
#       'grid.1010.0',
#       'grid.16872.3a',
#       'grid.63984.30',
#       'grid.21613.37']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Jin',
#      'id': 'ur.01212326461.29',
#      'last_name': 'Luo',
#      'orcid_id': ['0000-0002-9462-2016'],
#      'research_orgs': ['grid.412687.e',
#       'grid.17091.3e',
#       'grid.25073.33',
#       'grid.2515.3',
#       'grid.17063.33',
#       'grid.28046.38',
#       'grid.42327.30',
#       'grid.48336.3a',
#       'grid.56302.32',
#       'grid.416193.8',
#       'grid.418647.8',
#       'grid.65499.37',
#       'grid.415502.7',
#       'grid.14709.3b']},
#     {'first_name': 'Jessica',
#      'id': 'ur.01021574357.76',
#      'last_name': 'Widdifield',
#      'orcid_id': ['0000-0002-7464-0460'],
#      'research_orgs': ['grid.418647.8',
#       'grid.17063.33',
#       'grid.63984.30',
#       'grid.417199.3',
#       'grid.14709.3b',
#       'grid.416448.b',
#       'grid.25073.33',
#       'grid.416167.3',
#       'grid.416745.5',
#       'grid.498791.a',
#       'grid.39381.30',
#       'grid.413104.3',
#       'grid.22072.35',
#       'grid.416166.2',
#       'grid.416193.8']},
#     {'first_name': 'Nigil',
#      'id': 'ur.01344457140.05',
#      'last_name': 'Haroon',
#      'orcid_id': ['0000-0003-3210-4771'],
#      'research_orgs': ['grid.465547.1',
#       'grid.39381.30',
#       'grid.231844.8',
#       'grid.17091.3e',
#       'grid.23856.3a',
#       'grid.418905.1',
#       'grid.42327.30',
#       'grid.10776.37',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.263138.d',
#       'grid.416193.8',
#       'grid.413485.f',
#       'grid.492504.e',
#       'grid.417188.3']}],
#    'score': 1.0,
#    'title': 'Crude incidence rates of deliberate self-harm attempt and disposition following emergency department presentations in RA, AS and matched comparators.',
#    'year': 2020},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0229273',
#     'id': 'pub.1125058791',
#     'pmcid': 'PMC7034875',
#     'pmid': '32084192'},
#    'associated_publication_id': 'pub.1125058791',
#    'authors': [{'name': 'Bindee Kuriya'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Jin Luo'},
#     {'name': 'Jessica Widdifield'},
#     {'name': 'Nigil Haroon'}],
#    'category_bra': [{'id': '4001', 'name': 'Clinical Medicine and Science'}],
#    'category_for': [{'id': '80020', 'name': '49 Mathematical Sciences'},
#     {'id': '80137', 'name': '4202 Epidemiology'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_for_2020': [{'id': '80020', 'name': '49 Mathematical Sciences'},
#     {'id': '80137', 'name': '4202 Epidemiology'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_hrcs_hc': [{'id': '903',
#      'name': 'Inflammatory and immune system'}],
#    'category_rcdc': [{'id': '496', 'name': 'Autoimmune Disease'},
#     {'id': '304', 'name': 'Arthritis'}],
#    'date': '2020-02-21',
#    'date_created': '2020-02-21',
#    'date_inserted': '2020-02-21',
#    'date_modified': '2023-06-03',
#    'description': 'Unadjusted, univariable and multivariable adjusted hazard ratios (HR) with 95% confidence intervals (95% CI) for a deliberate self-harm attempt among individuals with rheumatoid arthritis or ankylosing spondylitis.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.7589221',
#    'doi': '10.1371/journal.pone.0229273.t003',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Unadjusted_univariable_and_multivariable_adjusted_hazard_ratios_HR_with_95_confidence_intervals_95_CI_for_a_deliberate_self-harm_attempt_among_individuals_with_rheumatoid_arthritis_or_ankylosing_spondylitis_/11884497',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'MHLTC',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415822.8',
#      'latitude': 43.7773,
#      'linkout': ['http://www.health.gov.on.ca/en/'],
#      'longitude': -79.52799,
#      'name': 'Ministry of Health and Long Term Care',
#      'state_name': 'Ontario',
#      'types': ['Government']},
#     {'acronym': 'Arthritis Society',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.469795.0',
#      'latitude': 43.654022,
#      'linkout': ['https://arthritis.ca/'],
#      'longitude': -79.387245,
#      'name': 'Arthritis Society',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'id': 'dataset.7589221',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['health service utilization variables',
#     'RA',
#     'population-based cohort studies',
#     'crude incidence rate',
#     'HR',
#     'PY',
#     'IR',
#     'ankylosing spondylitis',
#     'DSH',
#     'population-based cohort study Objective Rheumatoid arthritis',
#     'emergency department data',
#     'self-harm',
#     'CI',
#     'comparator',
#     'AS'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'acronym': 'ICES',
#      'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.418647.8',
#      'latitude': 43.723167,
#      'linkout': ['http://www.ices.on.ca/'],
#      'longitude': -79.372536,
#      'name': 'Institute for Clinical Evaluative Sciences',
#      'state_name': 'Ontario',
#      'types': ['Nonprofit']}],
#    'researchers': [{'first_name': 'Bindee',
#      'id': 'ur.01222076773.99',
#      'last_name': 'Kuriya',
#      'research_orgs': ['grid.5386.8',
#       'grid.22072.35',
#       'grid.8051.c',
#       'grid.28046.38',
#       'grid.475435.4',
#       'grid.26009.3d',
#       'grid.265892.2',
#       'grid.6518.a',
#       'grid.86715.3d',
#       'grid.416193.8',
#       'grid.25073.33',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.38142.3c',
#       'grid.492573.e',
#       'grid.416448.b',
#       'grid.17063.33',
#       'grid.498791.a',
#       'grid.17089.37',
#       'grid.411439.a',
#       'grid.416166.2',
#       'grid.462844.8',
#       'grid.416167.3',
#       'grid.1010.0',
#       'grid.16872.3a',
#       'grid.63984.30',
#       'grid.21613.37']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Jin',
#      'id': 'ur.01212326461.29',
#      'last_name': 'Luo',
#      'orcid_id': ['0000-0002-9462-2016'],
#      'research_orgs': ['grid.412687.e',
#       'grid.17091.3e',
#       'grid.25073.33',
#       'grid.2515.3',
#       'grid.17063.33',
#       'grid.28046.38',
#       'grid.42327.30',
#       'grid.48336.3a',
#       'grid.56302.32',
#       'grid.416193.8',
#       'grid.418647.8',
#       'grid.65499.37',
#       'grid.415502.7',
#       'grid.14709.3b']},
#     {'first_name': 'Jessica',
#      'id': 'ur.01021574357.76',
#      'last_name': 'Widdifield',
#      'orcid_id': ['0000-0002-7464-0460'],
#      'research_orgs': ['grid.418647.8',
#       'grid.17063.33',
#       'grid.63984.30',
#       'grid.417199.3',
#       'grid.14709.3b',
#       'grid.416448.b',
#       'grid.25073.33',
#       'grid.416167.3',
#       'grid.416745.5',
#       'grid.498791.a',
#       'grid.39381.30',
#       'grid.413104.3',
#       'grid.22072.35',
#       'grid.416166.2',
#       'grid.416193.8']},
#     {'first_name': 'Nigil',
#      'id': 'ur.01344457140.05',
#      'last_name': 'Haroon',
#      'orcid_id': ['0000-0003-3210-4771'],
#      'research_orgs': ['grid.465547.1',
#       'grid.39381.30',
#       'grid.231844.8',
#       'grid.17091.3e',
#       'grid.23856.3a',
#       'grid.418905.1',
#       'grid.42327.30',
#       'grid.10776.37',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.263138.d',
#       'grid.416193.8',
#       'grid.413485.f',
#       'grid.492504.e',
#       'grid.417188.3']}],
#    'score': 1.0,
#    'title': 'Unadjusted, univariable and multivariable adjusted hazard ratios (HR) with 95% confidence intervals (95% CI) for a deliberate self-harm attempt among individuals with rheumatoid arthritis or ankylosing spondylitis.',
#    'year': 2020},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0270158',
#     'id': 'pub.1148859253',
#     'pmcid': 'PMC9216596',
#     'pmid': '35731809'},
#    'associated_publication_id': 'pub.1148859253',
#    'authors': [{'name': 'Cindy-Lee Dennis'},
#     {'name': 'Hilary K. Brown'},
#     {'name': 'Sarah Brennenstuhl'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Ainsley Miller'},
#     {'name': 'Rita Amiel Castro'},
#     {'name': 'Flavia Casasanta Marini'},
#     {'name': 'Catherine Birken'}],
#    'date': '2022-06-22',
#    'date_created': '2022-06-22',
#    'date_inserted': '2022-06-27',
#    'date_modified': '2023-05-31',
#    'description': '(XLS)',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.58368219',
#    'doi': '10.1371/journal.pone.0270158.s001',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/S1_Dataset_-/20125463',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'CIHR',
#      'city_name': 'Ottawa',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.248883.d',
#      'latitude': 45.381893,
#      'linkout': ['http://www.cihr-irsc.gc.ca/e/193.html'],
#      'longitude': -75.745224,
#      'name': 'Canadian Institutes of Health Research',
#      'state_name': 'Ontario',
#      'types': ['Government']}],
#    'id': 'dataset.58368219',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['significant positive impact',
#     'poorer eating habits',
#     'decreased physical activity',
#     'preconception care needs',
#     'several risk factors',
#     'psychosocial risk factors',
#     'psychotropic medication management',
#     'health care needs',
#     'general physical health',
#     'chronic health conditions',
#     'also investigated differences',
#     'risk health behaviours',
#     'many important reproductive',
#     'without mental illness',
#     'preconception risk factors',
#     'perinatal risk factors',
#     'including increased rates',
#     'current mental illness',
#     '38 ), anxiety',
#     'xlink "> individuals',
#     'risk factors',
#     'mental illness',
#     'xlink ">',
#     'preconception interventions',
#     'perinatal outcomes',
#     'medication use',
#     'health trajectories',
#     'also determined',
#     '55 ),',
#     'suboptimal reproductive',
#     'current depression',
#     'neither condition',
#     'nationwide survey',
#     'nationwide study',
#     'internet addiction',
#     'identified areas',
#     'focuses primarily',
#     'comparing individuals',
#     'across canada',
#     '413 ).'],
#    'language_desc': 'id',
#    'language_title': 'id',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6166142', 'name': 'Thunder Bay'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'DE', 'name': 'Germany'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415502.7',
#      'latitude': 43.6532,
#      'linkout': ['http://www.stmichaelshospital.com/'],
#      'longitude': -79.3775,
#      'name': "St. Michael's Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Thunder Bay',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.258900.6',
#      'latitude': 48.421017,
#      'linkout': ['https://www.lakeheadu.ca/about'],
#      'longitude': -89.25645,
#      'name': 'Lakehead University',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.42327.30',
#      'latitude': 43.65773,
#      'linkout': ['http://www.sickkids.ca/'],
#      'longitude': -79.386986,
#      'name': 'Hospital for Sick Children',
#      'state_name': 'Ontario',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Cindy-Lee Elizabeth',
#      'id': 'ur.0611365265.81',
#      'last_name': 'Dennis',
#      'orcid_id': ['0000-0002-0135-7242'],
#      'research_orgs': ['grid.418647.8',
#       'grid.1022.1',
#       'grid.250674.2',
#       'grid.416100.2',
#       'grid.415502.7',
#       'grid.417199.3',
#       'grid.17063.33',
#       'grid.1018.8',
#       'grid.417191.b',
#       'grid.25073.33',
#       'grid.1003.2',
#       'grid.416107.5',
#       'grid.155956.b',
#       'grid.416166.2',
#       'grid.22072.35',
#       'grid.266904.f',
#       'grid.413104.3']},
#     {'first_name': 'Hilary K',
#      'id': 'ur.016623162752.04',
#      'last_name': 'Brown',
#      'orcid_id': ['0000-0002-8690-5841'],
#      'research_orgs': ['grid.410356.5',
#       'grid.413104.3',
#       'grid.261331.4',
#       'grid.25073.33',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.418647.8',
#       'grid.415502.7',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.413953.9',
#       'grid.155956.b',
#       'grid.28046.38']},
#     {'first_name': 'Sarah',
#      'id': 'ur.01216141473.50',
#      'last_name': 'Brennenstuhl',
#      'orcid_id': ['0000-0002-2538-582X'],
#      'research_orgs': ['grid.155956.b',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.42327.30',
#       'grid.417199.3',
#       'grid.415502.7']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Ainsley',
#      'id': 'ur.011043236506.92',
#      'last_name': 'Miller',
#      'orcid_id': ['0000-0001-5586-1578'],
#      'research_orgs': ['grid.258900.6']},
#     {'first_name': 'Rita Amiel',
#      'id': 'ur.07753312317.23',
#      'last_name': 'Castro',
#      'research_orgs': ['grid.7400.3', 'grid.7445.2']},
#     {'first_name': 'Flavia Casasanta',
#      'id': 'ur.010174012467.80',
#      'last_name': 'Marini',
#      'orcid_id': ['0000-0003-4158-9563'],
#      'research_orgs': ['grid.415502.7', 'grid.17063.33']},
#     {'first_name': 'Catherine Sari',
#      'id': 'ur.0714341612.10',
#      'last_name': 'Birken',
#      'orcid_id': ['0000-0003-0308-8645'],
#      'research_orgs': ['grid.418647.8',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.17089.37',
#       'grid.4830.f',
#       'grid.42327.30',
#       'grid.414148.c',
#       'grid.414114.5',
#       'grid.55602.34',
#       'grid.411418.9',
#       'grid.264756.4',
#       'grid.28046.38',
#       'grid.14848.31',
#       'grid.4494.d',
#       'grid.32566.34']}],
#    'score': 1.0,
#    'title': 'S1 Dataset -',
#    'year': 2022},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0270158',
#     'id': 'pub.1148859253',
#     'pmcid': 'PMC9216596',
#     'pmid': '35731809'},
#    'associated_publication_id': 'pub.1148859253',
#    'authors': [{'name': 'Cindy-Lee Dennis'},
#     {'name': 'Hilary K. Brown'},
#     {'name': 'Sarah Brennenstuhl'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Ainsley Miller'},
#     {'name': 'Rita Amiel Castro'},
#     {'name': 'Flavia Casasanta Marini'},
#     {'name': 'Catherine Birken'}],
#    'category_bra': [{'id': '4003', 'name': 'Public Health'}],
#    'category_for': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_for_2020': [{'id': '80023', 'name': '52 Psychology'},
#     {'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_hra': [{'id': '3901', 'name': 'Clinical'}],
#    'category_hrcs_hc': [{'id': '905', 'name': 'Mental health'}],
#    'category_hrcs_rac': [{'id': '10203',
#      'name': '2.3 Psychological, social and economic factors'},
#     {'id': '10606', 'name': '6.6 Psychological and behavioural'}],
#    'date': '2022-06-22',
#    'date_created': '2022-06-22',
#    'date_inserted': '2022-06-27',
#    'date_modified': '2023-06-01',
#    'description': 'Characteristics of individuals with depression, anxiety, and comorbidity compared to those without mental illness.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.58368218',
#    'doi': '10.1371/journal.pone.0270158.t001',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Characteristics_of_individuals_with_depression_anxiety_and_comorbidity_compared_to_those_without_mental_illness_/20125466',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'CIHR',
#      'city_name': 'Ottawa',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.248883.d',
#      'latitude': 45.381893,
#      'linkout': ['http://www.cihr-irsc.gc.ca/e/193.html'],
#      'longitude': -75.745224,
#      'name': 'Canadian Institutes of Health Research',
#      'state_name': 'Ontario',
#      'types': ['Government']}],
#    'id': 'dataset.58368218',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['significant positive impact',
#     'poorer eating habits',
#     'decreased physical activity',
#     'preconception care needs',
#     'several risk factors',
#     'psychosocial risk factors',
#     'psychotropic medication management',
#     'health care needs',
#     'general physical health',
#     'chronic health conditions',
#     'also investigated differences',
#     'risk health behaviours',
#     'many important reproductive',
#     'without mental illness',
#     'preconception risk factors',
#     'perinatal risk factors',
#     'including increased rates',
#     'current mental illness',
#     '38 ), anxiety',
#     'xlink "> individuals',
#     'risk factors',
#     'mental illness',
#     'xlink ">',
#     'preconception interventions',
#     'perinatal outcomes',
#     'medication use',
#     'health trajectories',
#     'also determined',
#     '55 ),',
#     'suboptimal reproductive',
#     'current depression',
#     'neither condition',
#     'nationwide survey',
#     'nationwide study',
#     'internet addiction',
#     'identified areas',
#     'focuses primarily',
#     'comparing individuals',
#     'across canada',
#     '413 ).'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6166142', 'name': 'Thunder Bay'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'DE', 'name': 'Germany'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415502.7',
#      'latitude': 43.6532,
#      'linkout': ['http://www.stmichaelshospital.com/'],
#      'longitude': -79.3775,
#      'name': "St. Michael's Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Thunder Bay',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.258900.6',
#      'latitude': 48.421017,
#      'linkout': ['https://www.lakeheadu.ca/about'],
#      'longitude': -89.25645,
#      'name': 'Lakehead University',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.42327.30',
#      'latitude': 43.65773,
#      'linkout': ['http://www.sickkids.ca/'],
#      'longitude': -79.386986,
#      'name': 'Hospital for Sick Children',
#      'state_name': 'Ontario',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Cindy-Lee Elizabeth',
#      'id': 'ur.0611365265.81',
#      'last_name': 'Dennis',
#      'orcid_id': ['0000-0002-0135-7242'],
#      'research_orgs': ['grid.418647.8',
#       'grid.1022.1',
#       'grid.250674.2',
#       'grid.416100.2',
#       'grid.415502.7',
#       'grid.417199.3',
#       'grid.17063.33',
#       'grid.1018.8',
#       'grid.417191.b',
#       'grid.25073.33',
#       'grid.1003.2',
#       'grid.416107.5',
#       'grid.155956.b',
#       'grid.416166.2',
#       'grid.22072.35',
#       'grid.266904.f',
#       'grid.413104.3']},
#     {'first_name': 'Hilary K',
#      'id': 'ur.016623162752.04',
#      'last_name': 'Brown',
#      'orcid_id': ['0000-0002-8690-5841'],
#      'research_orgs': ['grid.410356.5',
#       'grid.413104.3',
#       'grid.261331.4',
#       'grid.25073.33',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.418647.8',
#       'grid.415502.7',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.413953.9',
#       'grid.155956.b',
#       'grid.28046.38']},
#     {'first_name': 'Sarah',
#      'id': 'ur.01216141473.50',
#      'last_name': 'Brennenstuhl',
#      'orcid_id': ['0000-0002-2538-582X'],
#      'research_orgs': ['grid.155956.b',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.42327.30',
#       'grid.417199.3',
#       'grid.415502.7']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Ainsley',
#      'id': 'ur.011043236506.92',
#      'last_name': 'Miller',
#      'orcid_id': ['0000-0001-5586-1578'],
#      'research_orgs': ['grid.258900.6']},
#     {'first_name': 'Rita Amiel',
#      'id': 'ur.07753312317.23',
#      'last_name': 'Castro',
#      'research_orgs': ['grid.7400.3', 'grid.7445.2']},
#     {'first_name': 'Flavia Casasanta',
#      'id': 'ur.010174012467.80',
#      'last_name': 'Marini',
#      'orcid_id': ['0000-0003-4158-9563'],
#      'research_orgs': ['grid.415502.7', 'grid.17063.33']},
#     {'first_name': 'Catherine Sari',
#      'id': 'ur.0714341612.10',
#      'last_name': 'Birken',
#      'orcid_id': ['0000-0003-0308-8645'],
#      'research_orgs': ['grid.418647.8',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.17089.37',
#       'grid.4830.f',
#       'grid.42327.30',
#       'grid.414148.c',
#       'grid.414114.5',
#       'grid.55602.34',
#       'grid.411418.9',
#       'grid.264756.4',
#       'grid.28046.38',
#       'grid.14848.31',
#       'grid.4494.d',
#       'grid.32566.34']}],
#    'score': 1.0,
#    'title': 'Characteristics of individuals with depression, anxiety, and comorbidity compared to those without mental illness.',
#    'year': 2022},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0270158',
#     'id': 'pub.1148859253',
#     'pmcid': 'PMC9216596',
#     'pmid': '35731809'},
#    'associated_publication_id': 'pub.1148859253',
#    'authors': [{'name': 'Cindy-Lee Dennis'},
#     {'name': 'Hilary K. Brown'},
#     {'name': 'Sarah Brennenstuhl'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Ainsley Miller'},
#     {'name': 'Rita Amiel Castro'},
#     {'name': 'Flavia Casasanta Marini'},
#     {'name': 'Catherine Birken'}],
#    'category_bra': [{'id': '4003', 'name': 'Public Health'}],
#    'category_for': [{'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80023', 'name': '52 Psychology'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_for_2020': [{'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80023', 'name': '52 Psychology'},
# ...
#     'general physical health',
#     'chronic health conditions',
#     'also investigated differences',
#     'risk health behaviours',
#     'many important reproductive',
#     'without mental illness',
#     'preconception risk factors',
#     'perinatal risk factors',
#     'including increased rates',
#     'current mental illness',
#     '38 ), anxiety',
#     'xlink "> individuals',
#     'risk factors',
#     'mental illness',
#     'xlink ">',
#     'preconception interventions',
#     'perinatal outcomes',
#     'medication use',
#     'health trajectories',
#     'also determined',
#     '55 ),',
#     'suboptimal reproductive',
#     'current depression',
#     'neither condition',
#     'nationwide survey',
#     'nationwide study',
#     'internet addiction',
#     'identified areas',
#     'focuses primarily',
#     'comparing individuals',
#     'across canada',
#     '413 ).'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6166142', 'name': 'Thunder Bay'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'DE', 'name': 'Germany'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415502.7',
#      'latitude': 43.6532,
#      'linkout': ['http://www.stmichaelshospital.com/'],
#      'longitude': -79.3775,
#      'name': "St. Michael's Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Thunder Bay',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.258900.6',
#      'latitude': 48.421017,
#      'linkout': ['https://www.lakeheadu.ca/about'],
#      'longitude': -89.25645,
#      'name': 'Lakehead University',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.42327.30',
#      'latitude': 43.65773,
#      'linkout': ['http://www.sickkids.ca/'],
#      'longitude': -79.386986,
#      'name': 'Hospital for Sick Children',
#      'state_name': 'Ontario',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Cindy-Lee Elizabeth',
#      'id': 'ur.0611365265.81',
#      'last_name': 'Dennis',
#      'orcid_id': ['0000-0002-0135-7242'],
#      'research_orgs': ['grid.418647.8',
#       'grid.1022.1',
#       'grid.250674.2',
#       'grid.416100.2',
#       'grid.415502.7',
#       'grid.417199.3',
#       'grid.17063.33',
#       'grid.1018.8',
#       'grid.417191.b',
#       'grid.25073.33',
#       'grid.1003.2',
#       'grid.416107.5',
#       'grid.155956.b',
#       'grid.416166.2',
#       'grid.22072.35',
#       'grid.266904.f',
#       'grid.413104.3']},
#     {'first_name': 'Hilary K',
#      'id': 'ur.016623162752.04',
#      'last_name': 'Brown',
#      'orcid_id': ['0000-0002-8690-5841'],
#      'research_orgs': ['grid.410356.5',
#       'grid.413104.3',
#       'grid.261331.4',
#       'grid.25073.33',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.418647.8',
#       'grid.415502.7',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.413953.9',
#       'grid.155956.b',
#       'grid.28046.38']},
#     {'first_name': 'Sarah',
#      'id': 'ur.01216141473.50',
#      'last_name': 'Brennenstuhl',
#      'orcid_id': ['0000-0002-2538-582X'],
#      'research_orgs': ['grid.155956.b',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.42327.30',
#       'grid.417199.3',
#       'grid.415502.7']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Ainsley',
#      'id': 'ur.011043236506.92',
#      'last_name': 'Miller',
#      'orcid_id': ['0000-0001-5586-1578'],
#      'research_orgs': ['grid.258900.6']},
#     {'first_name': 'Rita Amiel',
#      'id': 'ur.07753312317.23',
#      'last_name': 'Castro',
#      'research_orgs': ['grid.7400.3', 'grid.7445.2']},
#     {'first_name': 'Flavia Casasanta',
#      'id': 'ur.010174012467.80',
#      'last_name': 'Marini',
#      'orcid_id': ['0000-0003-4158-9563'],
#      'research_orgs': ['grid.415502.7', 'grid.17063.33']},
#     {'first_name': 'Catherine Sari',
#      'id': 'ur.0714341612.10',
#      'last_name': 'Birken',
#      'orcid_id': ['0000-0003-0308-8645'],
#      'research_orgs': ['grid.418647.8',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.17089.37',
#       'grid.4830.f',
#       'grid.42327.30',
#       'grid.414148.c',
#       'grid.414114.5',
#       'grid.55602.34',
#       'grid.411418.9',
#       'grid.264756.4',
#       'grid.28046.38',
#       'grid.14848.31',
#       'grid.4494.d',
#       'grid.32566.34']}],
#    'score': 1.0,
#    'title': 'Adjusted odds of psychosocial risk factors, general physical health indicators, medication use, and high-risk health behaviours among individuals with depression, anxiety, and comorbidity compared to those without mental illness a.',
#    'year': 2022},
#   {'associated_publication': {'doi': '10.1371/journal.pone.0270158',
#     'id': 'pub.1148859253',
#     'pmcid': 'PMC9216596',
#     'pmid': '35731809'},
#    'associated_publication_id': 'pub.1148859253',
#    'authors': [{'name': 'Cindy-Lee Dennis'},
#     {'name': 'Hilary K. Brown'},
#     {'name': 'Sarah Brennenstuhl'},
#     {'name': 'Simone Vigod'},
#     {'name': 'Ainsley Miller'},
#     {'name': 'Rita Amiel Castro'},
#     {'name': 'Flavia Casasanta Marini'},
#     {'name': 'Catherine Birken'}],
#    'category_bra': [{'id': '4003', 'name': 'Public Health'}],
#    'category_for': [{'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80023', 'name': '52 Psychology'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80140', 'name': '4205 Nursing'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_for_2020': [{'id': '80013', 'name': '42 Health Sciences'},
#     {'id': '80023', 'name': '52 Psychology'},
#     {'id': '80138', 'name': '4203 Health Services and Systems'},
#     {'id': '80140', 'name': '4205 Nursing'},
#     {'id': '80013', 'name': '42 Health Sciences'}],
#    'category_hra': [{'id': '3902', 'name': 'Health services & systems'}],
#    'category_hrcs_hc': [{'id': '905', 'name': 'Mental health'}],
#    'category_hrcs_rac': [{'id': '10701', 'name': '7.1 Individual care needs'}],
#    'category_rcdc': [{'id': '437', 'name': 'Depression'},
#     {'id': '501', 'name': 'Brain Disorders'},
#     {'id': '380', 'name': 'Mental Health'},
#     {'id': '494', 'name': 'Anxiety Disorders'},
#     {'id': '498', 'name': 'Behavioral and Social Science'}],
#    'date': '2022-06-22',
#    'date_created': '2022-06-22',
#    'date_inserted': '2022-06-27',
#    'date_modified': '2023-06-04',
#    'description': 'Preconception health care use, attitudes, and knowledge among individuals with depression, anxiety, and comorbidity compared to those without mental illness a.',
#    'dimensions_url': 'https://app.dimensions.ai/details/data_set/dataset.58368215',
#    'doi': '10.1371/journal.pone.0270158.t003',
#    'figshare_url': 'https://plos.figshare.com/articles/dataset/Preconception_health_care_use_attitudes_and_knowledge_among_individuals_with_depression_anxiety_and_comorbidity_compared_to_those_without_mental_illness_sup_a_sup_/20125472',
#    'funder_countries': [{'id': 'CA', 'name': 'Canada'}],
#    'funders': [{'acronym': 'CIHR',
#      'city_name': 'Ottawa',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.248883.d',
#      'latitude': 45.381893,
#      'linkout': ['http://www.cihr-irsc.gc.ca/e/193.html'],
#      'longitude': -75.745224,
#      'name': 'Canadian Institutes of Health Research',
#      'state_name': 'Ontario',
#      'types': ['Government']}],
#    'id': 'dataset.58368215',
#    'journal': {'id': 'jour.1037553', 'title': 'PLOS ONE'},
#    'keywords': ['significant positive impact',
#     'poorer eating habits',
#     'decreased physical activity',
#     'preconception care needs',
#     'several risk factors',
#     'psychosocial risk factors',
#     'psychotropic medication management',
#     'health care needs',
#     'general physical health',
#     'chronic health conditions',
#     'also investigated differences',
#     'risk health behaviours',
#     'many important reproductive',
#     'without mental illness',
#     'preconception risk factors',
#     'perinatal risk factors',
#     'including increased rates',
#     'current mental illness',
#     '38 ), anxiety',
#     'xlink "> individuals',
#     'risk factors',
#     'mental illness',
#     'xlink ">',
#     'preconception interventions',
#     'perinatal outcomes',
#     'medication use',
#     'health trajectories',
#     'also determined',
#     '55 ),',
#     'suboptimal reproductive',
#     'current depression',
#     'neither condition',
#     'nationwide survey',
#     'nationwide study',
#     'internet addiction',
#     'identified areas',
#     'focuses primarily',
#     'comparing individuals',
#     'across canada',
#     '413 ).'],
#    'language_desc': 'en',
#    'language_title': 'en',
#    'license_name': 'CC BY 4.0',
#    'license_url': 'CC BY 4.0',
#    'research_org_cities': [{'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6167865', 'name': 'Toronto'},
#     {'id': '6166142', 'name': 'Thunder Bay'},
#     {'id': '6167865', 'name': 'Toronto'}],
#    'research_org_countries': [{'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'CA', 'name': 'Canada'},
#     {'id': 'DE', 'name': 'Germany'},
#     {'id': 'CA', 'name': 'Canada'}],
#    'research_org_states': [{'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'},
#     {'id': 'CA-ON', 'name': 'Ontario'}],
#    'research_orgs': [{'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.17063.33',
#      'latitude': 43.661667,
#      'linkout': ['http://www.utoronto.ca/'],
#      'longitude': -79.395,
#      'name': 'University of Toronto',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.415502.7',
#      'latitude': 43.6532,
#      'linkout': ['http://www.stmichaelshospital.com/'],
#      'longitude': -79.3775,
#      'name': "St. Michael's Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.417199.3',
#      'latitude': 43.661686,
#      'linkout': ['http://www.womenscollegehospital.ca/'],
#      'longitude': -79.3875,
#      'name': "Women's College Hospital",
#      'state_name': 'Ontario',
#      'types': ['Healthcare']},
#     {'city_name': 'Thunder Bay',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.258900.6',
#      'latitude': 48.421017,
#      'linkout': ['https://www.lakeheadu.ca/about'],
#      'longitude': -89.25645,
#      'name': 'Lakehead University',
#      'state_name': 'Ontario',
#      'types': ['Education']},
#     {'city_name': 'Toronto',
#      'country_code': 'CA',
#      'country_name': 'Canada',
#      'id': 'grid.42327.30',
#      'latitude': 43.65773,
#      'linkout': ['http://www.sickkids.ca/'],
#      'longitude': -79.386986,
#      'name': 'Hospital for Sick Children',
#      'state_name': 'Ontario',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Cindy-Lee Elizabeth',
#      'id': 'ur.0611365265.81',
#      'last_name': 'Dennis',
#      'orcid_id': ['0000-0002-0135-7242'],
#      'research_orgs': ['grid.418647.8',
#       'grid.1022.1',
#       'grid.250674.2',
#       'grid.416100.2',
#       'grid.415502.7',
#       'grid.417199.3',
#       'grid.17063.33',
#       'grid.1018.8',
#       'grid.417191.b',
#       'grid.25073.33',
#       'grid.1003.2',
#       'grid.416107.5',
#       'grid.155956.b',
#       'grid.416166.2',
#       'grid.22072.35',
#       'grid.266904.f',
#       'grid.413104.3']},
#     {'first_name': 'Hilary K',
#      'id': 'ur.016623162752.04',
#      'last_name': 'Brown',
#      'orcid_id': ['0000-0002-8690-5841'],
#      'research_orgs': ['grid.410356.5',
#       'grid.413104.3',
#       'grid.261331.4',
#       'grid.25073.33',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.418647.8',
#       'grid.415502.7',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.413953.9',
#       'grid.155956.b',
#       'grid.28046.38']},
#     {'first_name': 'Sarah',
#      'id': 'ur.01216141473.50',
#      'last_name': 'Brennenstuhl',
#      'orcid_id': ['0000-0002-2538-582X'],
#      'research_orgs': ['grid.155956.b',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.42327.30',
#       'grid.417199.3',
#       'grid.415502.7']},
#     {'first_name': 'Simone Natalie',
#      'id': 'ur.01004364646.61',
#      'last_name': 'Vigod',
#      'orcid_id': ['0000-0002-2736-9639'],
#      'research_orgs': ['grid.261331.4',
#       'grid.418647.8',
#       'grid.22072.35',
#       'grid.415502.7',
#       'grid.57544.37',
#       'grid.28046.38',
#       'grid.231844.8',
#       'grid.47100.32',
#       'grid.410356.5',
#       'grid.14709.3b',
#       'grid.417199.3',
#       'grid.39381.30',
#       'grid.46078.3d',
#       'grid.224260.0',
#       'grid.17063.33',
#       'grid.10698.36',
#       'grid.5608.b',
#       'grid.155956.b',
#       'grid.21613.37']},
#     {'first_name': 'Ainsley',
#      'id': 'ur.011043236506.92',
#      'last_name': 'Miller',
#      'orcid_id': ['0000-0001-5586-1578'],
#      'research_orgs': ['grid.258900.6']},
#     {'first_name': 'Rita Amiel',
#      'id': 'ur.07753312317.23',
#      'last_name': 'Castro',
#      'research_orgs': ['grid.7400.3', 'grid.7445.2']},
#     {'first_name': 'Flavia Casasanta',
#      'id': 'ur.010174012467.80',
#      'last_name': 'Marini',
#      'orcid_id': ['0000-0003-4158-9563'],
#      'research_orgs': ['grid.415502.7', 'grid.17063.33']},
#     {'first_name': 'Catherine Sari',
#      'id': 'ur.0714341612.10',
#      'last_name': 'Birken',
#      'orcid_id': ['0000-0003-0308-8645'],
#      'research_orgs': ['grid.418647.8',
#       'grid.415502.7',
#       'grid.17063.33',
#       'grid.17089.37',
#       'grid.4830.f',
#       'grid.42327.30',
#       'grid.414148.c',
#       'grid.414114.5',
#       'grid.55602.34',
#       'grid.411418.9',
#       'grid.264756.4',
#       'grid.28046.38',
#       'grid.14848.31',
#       'grid.4494.d',
#       'grid.32566.34']}],
#    'score': 1.0,
#    'title': 'Preconception health care use, attitudes, and knowledge among individuals with depression, anxiety, and comorbidity compared to those without mental illness a.',
#    'year': 2022}]}
