# %%
import dimcli
from dimcli.utils import *
import re
import psycopg2

import os, sys, time, json
from tqdm.notebook import tqdm as progressbar

import pandas as pd

import plotly.express as px
from plotly.offline import plot
if not 'google.colab' in sys.modules:
  # make js dependecies local / needed by html exports
    from plotly.offline import init_notebook_mode
    init_notebook_mode(connected=True)

print("==\nLogging in..")
# https://digital-science.github.io/dimcli/getting-started.html#authentication
ENDPOINT = "https://app.dimensions.ai"
if 'google.colab' in sys.modules:
    import getpass
    KEY = getpass.getpass(prompt='API Key: ')  
    dimcli.login(key=KEY, endpoint=ENDPOINT)
else:
    KEY = "9F8D648F0D7E437CB1736BEBDF007F02"
    dimcli.login(key=KEY, endpoint=ENDPOINT)
dsl = dimcli.Dsl()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ==
# Logging in..
# Dimcli - Dimensions API Client (v1.2)
# Connected to: <https://app.dimensions.ai/api/dsl> - DSL v2.8
# Method: manual login

# %%
# Specify the path to your JSON file
id_path = 'asci_aap_dataJSON.json'

# Initialize an empty dictionary
id_dictionary = {}

try:
    # Open the JSON file in read mode
    with open(id_path, 'r') as json_file:
        # Load the JSON data into the dictionary
        id_dictionary = json.load(json_file)
except FileNotFoundError:
    print("JSON file not found.")
except json.JSONDecodeError:
    print("Error decoding JSON data.")

# %%
def execute_command(query):
    try:
        connection = psycopg2.connect(
            "postgresql://selina04_mit_edu:iXr9mWuy_K_OSQv-tVgEug@livid-dibbler-6457.g8z.cockroachlabs.cloud:26257/livid-dibbler-6457.grants?sslmode=verify-full"
        )

        # Create a cursor and execute the insert statement
        cursor = connection.cursor()
        # print('This is current command: ',query)
        cursor.execute(query)
        connection.commit()  # Commit the transaction
        # print("Data inserted successfully")
        cursor.close()
        connection.close()

    except psycopg2.Error as error:
        print(f"Error: {query}")
        print("------")
        print(error)

# %%
query_work2_template = """search grants in investigators for "{}" return grants [abstract + active_year + concepts + concepts_scores + date_inserted + dimensions_url + end_date + funder_orgs + funding_usd + investigators + keywords + original_title + research_orgs + researchers + score + start_date + title + id + category_rcdc]"""

for author in id_dictionary["people"][20:35]:

    
    #Get the person's first and last name
    first_name = author["first_name"].strip(".")
    middle_name = author["middle_name"].strip(".")
    last_name = author["last_name"].strip(".")
    

    #Create a query name by combining the person's first and last name
    
    if author["middle_name"]: 
        author_name = first_name + " " + middle_name + " " + last_name
    else: 
        author_name = first_name + " " + last_name
    
    cleaned_name = re.sub(r'[^a-zA-Z0-9_]', '_', author_name)
    cleaned_name = re.sub(r'^\d', '_', cleaned_name)
    
    execute_command(f"""CREATE TABLE IF NOT EXISTS {cleaned_name} (
    id STRING PRIMARY KEY,
    abstract STRING,
    active_year STRING, 
    concepts STRING, 
    concepts_scores STRING,
    category_rcdc STRING,
    date_inserted STRING, 
    dimensions_url STRING,
    end_date STRING, 
    funder_orgs STRING, 
    funding_USD STRING, 
    investigators STRING,
    keywords STRING,
    original_title STRING, 
    research_orgs STRING,
    researchers STRING, 
    score STRING, 
    start_date STRING, 
    title STRING
);""")
            
    
    print(f"querying for {author_name}")
    q = query_work2_template.format(author_name)
    
    result = dsl.query_iterative(q, show_results=None, limit=100, skip=0, pause=1.5, force=False, maxlimit=0, verbose=None, _tot_count_prev_query=0, _warnings_tot=None)
    result_dict = result.data["grants"]
    
    for patent in result_dict: 
        fields = []
        values = []
        
        for field, value in patent.items():
            if not isinstance(value, str):
                # Convert non-string values to JSON string
                value = json.dumps(value);
            value = value.replace("'", "''")
            fields.append(field)
            values.append(f"'{value}'")  # Enclose string values in single quotes

        # Join the lists to create the SQL query
        columns = ', '.join(fields)
        values_str = ', '.join(values)

        insert_query = insert_query = f"INSERT INTO {cleaned_name} ({columns}) VALUES({values_str});"

        execute_command(insert_query)
# Out:
# Starting iteration with limit=100 skip=0 ...
# Error: CREATE TABLE IF NOT EXISTS Maria_T_Abreu (
#     id STRING PRIMARY KEY,
#     abstract STRING,
#     active_year STRING,
#     concepts STRING,
#     concepts_scores STRING,
#     date_inserted STRING,
#     dimensions_url STRING,
#     end_date STRING,
#     funder_orgs STRING,
#     funding_USD STRING,
#     investigators STRING,
#     keywords STRING,
#     original_title STRING,
#     research_orgs STRING,
#     researchers STRING,
#     score STRING,
#     start_date STRING,
#     title STRING
# );
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# querying for Maria T Abreu
# 0-5 / 5 (0.61s)
# ===
# Records extracted: 5
# Error: INSERT INTO Maria_T_Abreu (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('With the support of the Broad Foundation, we will conduct a dietary intervention study in patients with ulcerative colitis in whom medicines have not completely resolved their symptoms. Each participant will consume both a low fat diet and a standard American diet (SAD) in two consecutive periods of 4-weeks each. This study design will allow us to use each participant as her/his own control. The SAD represents what most Americans eat and what most of our patients with inflammatory bowel disease eat. We will provide daily meals throughout the duration of the intervention. We will assess whether the intervention changes symptoms, intestinal inflammation, and colonic bacteria. We will also determine how well participants follow the diet by comparing their recommended diet to actual diet in terms of percentage of fat and total caloric intake. The results of our study will provide a valuable source of information and guidance to patients and their physicians when asked about diet.', '[2014, 2015, 2016, 2017, 2018]', '["standard American diet", "ulcerative colitis", "inflammatory bowel disease", "dietary intervention study", "low-fat diet", "total caloric intake", "bowel disease", "intestinal inflammation", "fat diet", "dietary control", "caloric intake", "intervention studies", "own control", "American diet", "colonic bacteria", "patients", "study design", "diet", "daily meals", "colitis", "inflammation", "symptoms", "intervention", "participants", "consecutive periods", "actual diet", "terms of percentage", "disease", "physicians", "intake", "control", "fat", "study", "meal", "duration", "medicine", "most Americans", "percentage", "period", "Americans", "valuable source", "modifies", "guidance", "bacteria", "support", "broad foundation", "results", "information", "terms", "source", "design", "foundation"]', '[{"concept": "standard American diet", "relevance": 0.678}, {"concept": "ulcerative colitis", "relevance": 0.622}, {"concept": "inflammatory bowel disease", "relevance": 0.58}, {"concept": "dietary intervention study", "relevance": 0.576}, {"concept": "low-fat diet", "relevance": 0.576}, {"concept": "total caloric intake", "relevance": 0.574}, {"concept": "bowel disease", "relevance": 0.537}, {"concept": "intestinal inflammation", "relevance": 0.537}, {"concept": "fat diet", "relevance": 0.533}, {"concept": "dietary control", "relevance": 0.529}, {"concept": "caloric intake", "relevance": 0.529}, {"concept": "intervention studies", "relevance": 0.52}, {"concept": "own control", "relevance": 0.519}, {"concept": "American diet", "relevance": 0.515}, {"concept": "colonic bacteria", "relevance": 0.51}, {"concept": "patients", "relevance": 0.509}, {"concept": "study design", "relevance": 0.509}, {"concept": "diet", "relevance": 0.492}, {"concept": "daily meals", "relevance": 0.492}, {"concept": "colitis", "relevance": 0.489}, {"concept": "inflammation", "relevance": 0.485}, {"concept": "symptoms", "relevance": 0.478}, {"concept": "intervention", "relevance": 0.457}, {"concept": "participants", "relevance": 0.446}, {"concept": "consecutive periods", "relevance": 0.444}, {"concept": "actual diet", "relevance": 0.435}, {"concept": "terms of percentage", "relevance": 0.434}, {"concept": "disease", "relevance": 0.408}, {"concept": "physicians", "relevance": 0.408}, {"concept": "intake", "relevance": 0.405}, {"concept": "control", "relevance": 0.386}, {"concept": "fat", "relevance": 0.385}, {"concept": "study", "relevance": 0.381}, {"concept": "meal", "relevance": 0.379}, {"concept": "duration", "relevance": 0.378}, {"concept": "medicine", "relevance": 0.371}, {"concept": "most Americans", "relevance": 0.353}, {"concept": "percentage", "relevance": 0.351}, {"concept": "period", "relevance": 0.3 ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# Error: INSERT INTO Maria_T_Abreu (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('SCIENTIFIC SUMMARY OF THE PROJECTChronic inflammation in the intestine results in colon cancer or dysplasia in an important group of patients with ulcerative colitis and Crohn''s disease. Even though cancer is far less common than dysplasia, patients with dysplasia are advised to undergo colectomy or frequent colonoscopies for surveillance--both resulting in a reduced quality of life and increased medical costs. We wish to understand the process that leads from inflammation to cancer and, in particular, how the innate immune system cooperates in engendering inflammatory cancers in the intestine. Crosstalk between inflammatory pathways and oncogenic pathways may underlie this transition from inflammation and repair to neoplasia. The essential program for proliferation in the intestine is directed by the Wnt/beta-catenin axis. Mutations in the adenomatous polyposis coli (APC) gene result in constitutive activation of the beta-catenin pathway in most sporadic adenomas and cancers. Yet APC mutations do not occur in early dysplasia in IBD. Recent studies, however, have highlighted the role of Wnt/beta-catenin signaling in maintenance of colon cancer stem cells. Importantly for the current proposal, beta-catenin activation is seen in UC dysplasia and cancer. Toll-like receptor 4 (TLR4) is a pattern recognition receptor that activates innate immune pathways in response to LPS present on Gram-negative bacteria and also damage-associated molecular products (DAMPs) such as hyaluronan (HA) produced during intestinal inflammation. Our work on the regulation of TLR4 in the intestine has led us in an interesting direction that is highly relevant to understanding inflammatory cancers. In the current proposal, we wish to test the provocative hypothesis that bacterial signaling through TLR4 activates regenerating cells in the colon by stabilizing beta-catenin to induce proliferation and ultimately provide a neoplastic drive in colitis-associated cancer.We have shown that expression of TLR4 by intestinal epithelial cells (IECs) increases from dysplasia to cancer in UC (cover of July 2011 issue of IBD journal). This increase in TLR4 protein expression in dysplasia and cancer is distinctly abnormal since data we include demonstrate that TLR4 expression in the normal colon is very low and onlybasolateral. We present preliminary data that TLR4 signaling can induce rapid phosphorylation of GSK3beta and beta-catenin, increase nuclear beta-catenin, and induce expression of beta-catenin target genes. In vivo, we see that animals that have an increase in epithelial TLR4 signaling are prone to colitis-associated cancer (CAC) and show increased proliferation and stabilized beta-catenin even in non-dysplastic areas--supporting a role for beta-catenin activation as a drive to proliferation and neoplasia. We also demonstrate an expansion of Lgr5+ cells in mice expressing a TLR4 transgene under control of the villin promoter. This proposal seeks funding to characterize the mole', '[2012, 2013, 2014, 2015]', '["Toll-like receptor 4", "colitis-associated cancer", "inflammatory cancer", "regulation of TLR4", "expression of TLR4", "epithelial toll-like receptor 4", "beta-catenin activation", "expansion of Lgr5", "colitis-associated cancer", "TLR4 protein expression", "quality of life", "innate immune system", "pattern recognition receptors", "non-dysplastic areas", "cancer stem cells", "colon cancer stem cells", "stem cells", "frequent colonoscopy", "UC dysplasia", "role of Wnt", "TLR4 expression", "ulcerative colitis", "intestinal inflammation", "Crohn''s disease", "inflammatory pathways", "sporadic adenomas", "receptor 4", "villin promoter", "early dysplasia", "medical costs", "immune pathways", "intestine results", " ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
# Error: INSERT INTO Maria_T_Abreu (active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('[2007, 2008, 2009, 2010]', '["role of TLR4", "colitis-associated cancer", "TLR4", "cancer", "role"]', '[{"concept": "role of TLR4", "relevance": 0.156}, {"concept": "colitis-associated cancer", "relevance": 0.156}, {"concept": "TLR4", "relevance": 0.112}, {"concept": "cancer", "relevance": 0.11}, {"concept": "role", "relevance": 0.088}]', '2016-04-15', 'https://app.dimensions.ai/details/grant/grant.5029984', '2010-01-01', '[{"acronym": "CCF", "city_name": "New York", "country_code": "US", "country_name": "United States", "id": "grid.421660.7", "latitude": 40.761974, "linkout": ["http://www.crohnscolitisfoundation.org/"], "longitude": -74.05591, "name": "Crohn''s and Colitis Foundation", "state_name": "New York", "types": ["Nonprofit"]}]', '269714.0', 'grant.5029984', '[{"affiliations": [{"city": "Coral Gables", "city_id": "5368361", "country": "United States", "country_code": "US", "id": "grid.50956.3f", "name": "Cedars-Sinai Medical Center", "state": "FL", "state_code": "US-CA"}], "first_name": "Masayuki", "id": "ur.0636623611.12", "last_name": "Fukata", "middle_name": "", "role": "PI"}, {"affiliations": [{"city": "New York", "city_id": "5128581", "country": null, "country_code": "US", "id": "grid.59734.3c", "name": "Icahn School of Medicine at Mount Sinai", "state": "NY", "state_code": "US-NY"}], "first_name": "Steven", "id": "ur.0743333124.19", "last_name": "Itzkowitz", "middle_name": "H.", "role": "Co-PI"}, {"affiliations": [{"city": "Miami", "city_id": "4151871", "country": "United States", "country_code": "US", "id": "grid.26790.3a", "name": "Miller School of Medicine of the University of Miami", "state": "FL", "state_code": "US-FL"}], "first_name": "Maria", "id": "ur.0606477677.70", "last_name": "Abreu", "middle_name": "T.", "role": "Co-PI"}]', 'The role of TLR4 signaling in colitis-associated cancer', '[{"city_name": "Los Angeles", "country_code": "US", "country_name": "United States", "id": "grid.50956.3f", "latitude": 34.076286, "linkout": ["http://cedars-sinai.edu/"], "longitude": -118.38098, "name": "Cedars-Sinai Medical Center", "state_name": "California", "types": ["Healthcare"]}, {"acronym": "MSSM", "city_name": "New York", "country_code": "US", "country_name": "United States", "id": "grid.59734.3c", "latitude": 40.789085, "linkout": ["http://icahn.mssm.edu/"], "longitude": -73.95311, "name": "Icahn School of Medicine at Mount Sinai", "state_name": "New York", "types": ["Education"]}, {"acronym": "UM", "city_name": "Coral Gables", "country_code": "US", "country_name": "United States", "id": "grid.26790.3a", "latitude": 25.71694, "linkout": ["http://www.miami.edu/"], "longitude": -80.27577, "name": "University of Miami", "state_name": "Florida", "types": ["Education"]}]', '[{"first_name": "Masayuki", "id": "ur.0636623611.12", "last_name": "Fukata", "research_orgs": ["grid.59734.3c", "grid.416792.f", "grid.266093.8", "grid.416167.3", "grid.19006.3e", "grid.267301.1", "grid.50956.3f", "grid.261331.4", "grid.214458.e", "grid.26790.3a", "grid.134563.6"]}, {"first_name": "Steven H", "id": "ur.0743333124.19", "last_name": "Itzkowitz", "orcid_id": ["0000-0002-0436-5416"], "research_orgs": ["grid.240283.f", "grid.32224.35", "grid.251993.5", "grid.266100.3", "grid.26790.3a", "grid.415166.1", "grid.410800.d", "grid.280062.e", "grid.516104.7", "grid.416732.5", "grid.266102.1", "grid.410371.0", "grid.516081.b", "grid.59734.3c", "grid.21729.3f", "grid.411024.2", "grid.477517.7", "grid.410372.3", "grid.252858.0", "grid.418019.5", "grid.34477.33", "grid.416167.3"]}, {"first_name": "Maria Teresa", "id": "ur.0606477677.70", "last_name": "Abreu", "orcid_id": ["0000-0002-7294-0574"], "research_orgs": ["grid.28046.38", "grid.261331.4", "grid.410569.f", "grid.414905.d", "grid.266100.3", "grid.19006.3 ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# Error: INSERT INTO Maria_T_Abreu (active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('[2001, 2002, 2003]', '["dependent protection", "barrier function", "P13-kinase", "gut", "apoptosis", "FA", "role", "maintenance", "protection", "function"]', '[{"concept": "dependent protection", "relevance": 0.362}, {"concept": "barrier function", "relevance": 0.362}, {"concept": "P13-kinase", "relevance": 0.301}, {"concept": "gut", "relevance": 0.281}, {"concept": "apoptosis", "relevance": 0.277}, {"concept": "FA", "relevance": 0.249}, {"concept": "role", "relevance": 0.234}, {"concept": "maintenance", "relevance": 0.223}, {"concept": "protection", "relevance": 0.221}, {"concept": "function", "relevance": 0.212}]', '2016-04-15', 'https://app.dimensions.ai/details/grant/grant.5030413', '2003-03-31', '[{"acronym": "CCF", "city_name": "New York", "country_code": "US", "country_name": "United States", "id": "grid.421660.7", "latitude": 40.761974, "linkout": ["http://www.crohnscolitisfoundation.org/"], "longitude": -74.05591, "name": "Crohn''s and Colitis Foundation", "state_name": "New York", "types": ["Nonprofit"]}]', '184000.0', 'grant.5030413', '[{"affiliations": [{"city": "Miami", "city_id": "4151871", "country": "United States", "country_code": "US", "id": "grid.26790.3a", "name": "Miller School of Medicine of the University of Miami", "state": "FL", "state_code": "US-FL"}], "first_name": "Maria", "id": "ur.0606477677.70", "last_name": "Abreu", "middle_name": "T", "role": "PI"}]', 'P13''-Kinase-Dependent protection from Fas-Mediated apoptosis in the gut: Role in maintenance of barrier function', '[{"acronym": "UM", "city_name": "Coral Gables", "country_code": "US", "country_name": "United States", "id": "grid.26790.3a", "latitude": 25.71694, "linkout": ["http://www.miami.edu/"], "longitude": -80.27577, "name": "University of Miami", "state_name": "Florida", "types": ["Education"]}]', '[{"first_name": "Maria Teresa", "id": "ur.0606477677.70", "last_name": "Abreu", "orcid_id": ["0000-0002-7294-0574"], "research_orgs": ["grid.28046.38", "grid.261331.4", "grid.410569.f", "grid.414905.d", "grid.266100.3", "grid.19006.3e", "grid.26790.3a", "grid.410396.9", "grid.413105.2", "grid.214458.e", "grid.267301.1", "grid.22072.35", "grid.419791.3", "grid.50956.3f", "grid.59734.3c", "grid.14848.31", "grid.266093.8", "grid.416792.f", "grid.418456.a", "grid.134563.6", "grid.416167.3"]}]', '6.4697766', '2001-01-01', 'P13''-Kinase-Dependent protection from Fas-Mediated apoptosis in the gut: Role in maintenance of barrier function');
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# Error: INSERT INTO Maria_T_Abreu (active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('[1996, 1997]', '["secretin", "apoptosis", "cells", "mechanism"]', '[{"concept": "secretin", "relevance": 0.405}, {"concept": "apoptosis", "relevance": 0.384}, {"concept": "cells", "relevance": 0.361}, {"concept": "mechanism", "relevance": 0.315}]', '2016-04-15', 'https://app.dimensions.ai/details/grant/grant.5031355', '1997-12-31', '[{"acronym": "CCF", "city_name": "New York", "country_code": "US", "country_name": "United States", "id": "grid.421660.7", "latitude": 40.761974, "linkout": ["http://www.crohnscolitisfoundation.org/"], "longitude": -74.05591, "name": "Crohn''s and Colitis Foundation", "state_name": "New York", "types": ["Nonprofit"]}]', '138560.0', 'grant.5031355', '[{"affiliations": [{"city": "Miami", "city_id": "4151871", "country": "United States", "country_code": "US", "id": "grid.26790.3a", "name": "Miller School of Medicine of the University of Miami", "state": "FL", "state_code": "US-FL"}], "first_name": "Maria", "id": "ur.0606477677.70", "last_name": "Abreu", "middle_name": "T", "role": "PI"}]', 'Epithelial-immune interactions: elucidating the cellular and molecular  mechanisms that signal apoptosis of pro-inflammatory cytokine secretin in colonic epithelial  cells', '[{"acronym": "UM", "city_name": "Coral Gables", "country_code": "US", "country_name": "United States", "id": "grid.26790.3a", "latitude": 25.71694, "linkout": ["http://www.miami.edu/"], "longitude": -80.27577, "name": "University of Miami", "state_name": "Florida", "types": ["Education"]}]', '[{"first_name": "Maria Teresa", "id": "ur.0606477677.70", "last_name": "Abreu", "orcid_id": ["0000-0002-7294-0574"], "research_orgs": ["grid.28046.38", "grid.261331.4", "grid.410569.f", "grid.414905.d", "grid.266100.3", "grid.19006.3e", "grid.26790.3a", "grid.410396.9", "grid.413105.2", "grid.214458.e", "grid.267301.1", "grid.22072.35", "grid.419791.3", "grid.50956.3f", "grid.59734.3c", "grid.14848.31", "grid.266093.8", "grid.416792.f", "grid.418456.a", "grid.134563.6", "grid.416167.3"]}]', '6.4697766', '1996-01-01', 'Epithelial-immune interactions: elucidating the cellular and molecular  mechanisms that signal apoptosis of pro-inflammatory cytokine secretin in colonic epithelial  cells');
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
# Starting iteration with limit=100 skip=0 ...
# Error: CREATE TABLE IF NOT EXISTS Domenico_Accili (
#     id STRING PRIMARY KEY,
#     abstract STRING,
#     active_year STRING,
#     concepts STRING,
#     concepts_scores STRING,
#     date_inserted STRING,
#     dimensions_url STRING,
#     end_date STRING,
#     funder_orgs STRING,
#     funding_USD STRING,
#     investigators STRING,
#     keywords STRING,
#     original_title STRING,
#     research_orgs STRING,
#     researchers STRING,
#     score STRING,
#     start_date STRING,
#     title STRING
# );
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# querying for Domenico Accili
# 0-10 / 10 (3.76s)
# ===
# Records extracted: 10
# Error: INSERT INTO Domenico_Accili (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, keywords, original_title, research_orgs, researchers, score, start_date, title) VALUES('The marked increase in cardiovascular disease in patients with type 2 diabetes (T2D) demands an integrated cardiometabolic approach. Using this approach, the PPG team has had a highly interactive and productive collaboration for the last 10 years and plans to move forward to explore common transcriptional and signaling mechanisms in distinct cell types that contribute to cardiometabolic disease. This goal will be achieved through continued synergistic interactions among the 3 projects and Core A. Project 1 (Tabas) will explore how a common upstream CaMKII/MK2 pathway in hepatocytes (HCs) and macrophages (M s) promotes insulin resistance and plaque progression, respectively—and how the HC pathway amplifies the M  pathway through systemic insulin resistance. The project has a mechanism-based therapeutic/translational component and involves key collaborations with Drs. Tall and Accili. For example, Drs. Tabas & Tall will explore the novel finding that the M  CaMKII/MK2 pathway down- regulates LXR, thereby impairing a key atheroprotective process, efferocytosis. Project 2 (Tall) will explore the role of T39 in HCs, lesional M s, and adipocytes. In HCs and M s, T39 alters LXR activation to promote hepatosteatosis and block the suppressive effect of M  LXR on atherosclerosis. Thus, blocking T39 suppresses both atherosclerosis and fatty liver. Drs. Tall & Tabas with study the role of M  LXR in suppressing atherosclerosis in T39-deficient mice (above). In adipocytes T39 suppresses beiging, which may promote insulin resistance and atherosclerosis. The mechanism involves down-regulation of PPAR 1, which will be explored with Dr. Accili. Project 3 (Accili) addresses a key problem in T2D therapeutics, namely, thiazolidinedione (TZD) use is markedly limited by cardiogenic fluid retention and bone loss. Dr. Accili discovered that PPAR , the target of TZDs, can be deacetylated, which alters it function and response to TZDs. When TZDs are used in insulin-resistant mice expressing deacetylated mutant PPAR  ("2KR"), the insulin-sensitizing benefits remain but fluid retention and bone loss are prevented. With Drs. Tabas & Tall., Dr. Accili will investigate the relevance of these findings to atherosclerosis and will explore mechanism. For example, Drs. Accili & Tabas found that M s from 2KR mice have markedly enhanced efferocytosis, which predicts decreased plaque progression. 2KR mice also display adipose beiging, and Drs. Accili & Tall will assess the impact of this on atherogenesis. Core A (Drs. Wang and Wei) will provide essential support and integration for all of the atherosclerosis studies of the PPG and will also provide statistical and bioinformatic support to ensure rigor and reproducibility for all projects. In summary, through synergistic interactions among the PPG PIs, these new studies will reveal important new concepts and therapeutic targets related to the integrated pathophysiology of cardiometabolic disease.', '[2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]', '["insulin resistance", "cardiometabolic diseases", "bone loss", "fluid retention", "plaque progression", "systemic insulin resistance", "type 2 diabetes", "insulin-resistant mice", "mechanisms of atherogenesis", "thiazolidinedione use", "fatty liver", "Atherosclerosis Study", "cardiovascular disease", "LXR activation", "MK2 pathway", "therapeutic target", "atherosclerosis", "integrated pathophysiology", "suppressive effect", "T2D therapeutics", "atheroprotective process", "mice", "disease", "LXR", "marked increase", "synergistic interaction", "TZDs", "novel findings", "atherogenesis", "hepatocytes", "distinct cell types", "PPAR", "efferocytosis", "progression", " ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# Error: INSERT INTO Domenico_Accili (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, id, investigators, original_title, research_orgs, researchers, score, start_date, title) VALUES('The importance of insulin and leptin in the regulation of energy homeostasis through central nervous centers has become in recent years increasingly become the focus of obesity and diabetes research. Although insulin and leptin receptors belong to two different receptor classes, leads the stimulation of both receptors intracellularly to activate the PI3 kinase (PI3K). We have shown in the context of preparatory work that the constitutional activation of this pathway results in hypothalamic POMC neurons to diet-sensitive obesity with hyperphagia. About the function of PI3K pathway with regard to the inactivation of the transcription factor FOXO1 in hypothalamic neurons on the other hand, little is known. In contrast to the known effect of FOXO1 on transcription of gluconeogenesis-regulating enzymes in the liver, it is unclear what physiological effects exert transcriptional changes by FOXO1 in the CNS in vivo and in which cell populations insulin over FOXO1 affects energy homeostasis. Also is not fully understood on the molecular mechanisms FOXO1 activity is self-regulated. Firstly FOXO1 is inactivated by phosphorylation, on the other hand, however, the mechanism of acetylation seems to come up a role in the modulation of FOXO1 activity. The aim of this research project is therefore the analysis of the importance of transcriptional regulation by hypothalamic neurons in FOXO1 in vivo. To this end, transgenic mice for expression of various phosphorylation and acetylation modified FOXO1 mutants are created in defined hypothalamic neurons and characterized in detail in terms of energy homeostasis.', '[2006, 2007, 2008, 2009]', '["transcriptional regulation", "FoxO1 activity", "energy homeostasis", "transcription factor FOXO1", "hypothalamic neurons", "mechanism of acetylation", "PI3K pathway", "effect of FoxO1", "transcriptional changes", "PI3-kinase", "FOXO1 mutant", "different receptor classes", "K pathway", "FOXO1", "constitutional activation", "hypothalamic AgRP neurons", "importance of insulin", "hypothalamic POMC neurons", "homeostasis", "phosphorylation", "receptor class", "regulation", "acetylation", "AgRP neurons", "POMC neurons", "transgenic mice", "leptin receptor", "glucose homeostasis", "pathway", "physiological effects", "nervous centers", "neurons", "diabetes research", "insulin", "mutants", "transcription", "vivo", "obesity", "kinase", "receptors", "enzyme", "inactivation", "expression", "activity", "activation", "leptin", "hyperphagia", "CNS", "mice", "liver", "importance", "stimulation", "mechanism", "role", "effect", "modulation", "function", "aim", "years", "contrast", "recent years", "center", "hand", "changes", "analysis", "regard", "class", "end", "focus", "detail", "research", "context", "research project", "preparatory work", "work", "terms", "project", "energy"]', '[{"concept": "transcriptional regulation", "relevance": 0.738}, {"concept": "FoxO1 activity", "relevance": 0.705}, {"concept": "energy homeostasis", "relevance": 0.691}, {"concept": "transcription factor FOXO1", "relevance": 0.661}, {"concept": "hypothalamic neurons", "relevance": 0.649}, {"concept": "mechanism of acetylation", "relevance": 0.647}, {"concept": "PI3K pathway", "relevance": 0.64}, {"concept": "effect of FoxO1", "relevance": 0.637}, {"concept": "transcriptional changes", "relevance": 0.629}, {"concept": "PI3-kinase", "relevance": 0.628}, {"concept": "FOXO1 mutant", "relevance": 0.621}, {"concept": "different receptor classes", "relevance": 0.605}, {"concept": "K pathway", "relevance": 0.592}, {"concept": "FOXO1", "relevance": 0.59}, {"concept": "constitutional activation", "relevance": 0.586}, {"concept": "hypothalamic AgRP neurons", "relevance": 0.583}, {"concept": "importance of insulin", "relevan ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
# Error: INSERT INTO Domenico_Accili (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, keywords, original_title, research_orgs, researchers, score, start_date, title) VALUES('ABSTRACT Aim of this research is to understand why endocrine b-cells in the pancreas of diabetic patients fail, with an eye toward identifying new genetic, biochemical, and cellular pathways that can be exploited as therapeutic targets to prevent and reverse this disease process. This grant has supported several original and widely reproduced discoveries, identifying a homeostatic loop orchestrated by Foxo transcription factors that integrates disparate hormonal and nutrient signals into a gene expression program intended to preserve b-cell function and identity. Signal achievements of this work have been the demonstration of three stages leading to b-cell failure: metabolic inflexibility, b-cell conversion into other pancreatic cell types, and dedifferentiation into an endocrine progenitor-like state. Since the last competing renewal, this grant has supported several major new findings: (i) identification of human diabetes-enriched islet cell types and master regulatory activities driving cell-state transitions; (ii) discovery of BACH2 as a driver of b/a-cell transition and b-cell dedifferentiation in humans; (iii) discovery of AFF3 as a driver of human b/a-cell transition; (iv) pathogenic role of aldehyde dehydrogenase 1 isoform A3 (ALHD1A3) in metabolic inflexibility leading to b-cell failure; (v) description of a “recovering b-cell” signature associated with reversal of metabolic inflexibility; (vi) identification of C2CD4A as a human diabetes susceptibility gene with a role in suppressing b-cell “disallowed” genes, thereby controlling metabolic flexibility; (vii) functional demonstration that regulation of mitochondrial complex III function through the oxidoreductase Cyb5r3 is critical in the progression of metabolic inflexibility into b-cell failure; (viii) identification of vitamin D-binding protein (Gc) as a marker of a-to-b- cell transition and potential functional mediator of b-cell dysfunction; (ix) demonstration of antagonistic epistasis between FoxO1 and Hnf4a in b-cells. The PI proposes to extend this work with the following specific aims: In Aim 1, to test pharmacologically and mechanistically whether BACH2 inhibition can reverse b-cell dedifferentiation and a/b-cell-state transitions. In Aim 2, to test the ability of newly synthesized ALDH1A3 inhibitors to reverse metabolic inflexibility, restoring to b-cell function. In Aim 3 to characterize C2CD4A, a putative corepressor encoded by a human diabetes susceptibility locus, as a potential link between type 2 diabetes genetics and metabolic inflexibility in b-cell dysfunction. This body of work offers immediate, tangible therapeutic applications with the potential to prevent or reverse b-cell failure, thus ensuring that we move from disease management to disease modification. It is envisioned that the successful completion of these aims will lead to new diabetes therapeutics.', '[2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]', '["B-cell failure", "B-cell dysfunction", "B cell function", "metabolic inflexibility", "B cells", "cell transition", "cell types", "gene expression programs", "FOXO transcription factors", "cell state transitions", "progenitor-like state", "B cell transition", "type 2 diabetes genetics", "beta-cell failure", "pancreatic cell types", "diabetes susceptibility genes", "diabetes susceptibility locus", "antagonistic epistasis", "islet cell types", "putative corepressor", "expression programs", "nutrient signals", "transcription factors", "cellular pathways", "diabetic patients", "vitamin D", "metabolic flexibility", "diabetes genetics", "pathogenic role", "susceptibility loci", "therapeutic tar ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
#
# Error: INSERT INTO Domenico_Accili (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, keywords, original_title, research_orgs, researchers, score, start_date, title) VALUES('PROJECT SUMMARY/ABSTRACT Non-alcoholic fatty liver disease (NAFLD) is an under-appreciated complication of lipid dysmetabolism in type 2 diabetes (T2DM). Although it appears that insulin resistance (IR) is a mechanism common to both, the pathophysiology linking it to unhealthy fat accumulation in liver remains unclear. We propose that the hyperinsulinemia that accompanies IR drives the excessive hepatic de novo lipogenesis (DNL) that characterizes IR-associated NAFLD (IR- NAFLD). Our objective, therefore, is to observe the impact of lowering insulin levels on hepatic lipid metabolism in patients with insulin resistance (prediabetic state plus hyperinsulinemia) who are diagnosed with, or are at high risk for, NAFLD; we will accomplish this by using the somatostatin analogue- (octreotide-) assisted "pancreatic clamp" technique. In order to optimize pancreatic clamp conditions, we must first perform a pilot & feasibility study in which we test the effect of identifying and (1) maintaining the basal insulin infusion rate (IIR) ("maintenance hyperinsulinemia", MH protocol) versus (2) a stepwise decline in IIR to 90%, 75%, and 60% ("reduction toward euinsulinemia", RE protocol) of basal. All participants will be tested with both MH and RE protocols, in random order, separated by 2-4 weeks. We will evaluate changes in levels of glucose, insulin, and various lipid-metabolic parameters in order to gauge the insulin dose-glycemic response of insulin lowering and select the appropriate IIR to apply to the RE protocol in the main study.', '[2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027]', '["non-alcoholic fatty liver disease", "insulin resistance", "de novo lipogenesis", "RE protocol", "hepatic de novo lipogenesis", "Abstract Non-alcoholic fatty liver disease", "pancreatic clamp conditions", "lipid metabolic parameters", "fatty liver disease", "role of hyperinsulinemia", "type 2 diabetes", "hepatic lipid metabolism", "levels of glucose", "lipid dysmetabolism", "liver disease", "insulin levels", "pancreatic clamp", "fat accumulation", "high risk", "novo lipogenesis", "lipid metabolism", "random order", "clamp conditions", "hyperinsulinemia", "stepwise decline", "feasibility study", "insulin", "main study", "complications", "dysmetabolism", "diabetes", "patients", "pathophysiology", "somatostatin", "disease", "liver", "lipogenesis", "weeks", "study", "basal", "levels", "risk", "clamp", "metabolism", "protocol", "Versus", "glucose", "participants", "pilot", "resistance", "response", "decline", "role", "accumulation", "effect", "MH", "changes", "objective", "mechanism", "impact", "identifying", "IIR", "conditions", "technique", "order", "parameters"]', '[{"concept": "non-alcoholic fatty liver disease", "relevance": 0.75}, {"concept": "insulin resistance", "relevance": 0.665}, {"concept": "de novo lipogenesis", "relevance": 0.655}, {"concept": "RE protocol", "relevance": 0.62}, {"concept": "hepatic de novo lipogenesis", "relevance": 0.59}, {"concept": "Abstract Non-alcoholic fatty liver disease", "relevance": 0.583}, {"concept": "pancreatic clamp conditions", "relevance": 0.583}, {"concept": "lipid metabolic parameters", "relevance": 0.583}, {"concept": "fatty liver disease", "relevance": 0.58}, {"concept": "role of hyperinsulinemia", "relevance": 0.577}, {"concept": "type 2 diabetes", "relevance": 0.575}, {"concept": "hepatic lipid metabolism", "relevance": 0.571}, {"concept": "levels of glucose", "relevance": 0.549}, {"concept": "lipid dysmetabolism", "relevance": 0.538}, {"concept": "liver disease", "relevance": 0.536}, {"concept": "insulin levels", "relevance": 0.535}, {"concep ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
# Error: INSERT INTO Domenico_Accili (abstract, active_year, concepts, concepts_scores, date_inserted, dimensions_url, end_date, funder_orgs, funding_usd, id, investigators, keywords, original_title, research_orgs, researchers, score, start_date, title) VALUES('Insulin resistance stands as a significant threat to public health worldwide, and a largely unmet medical need. To unravel the complex biology of this protean syndrome, we have endeavored to apply genetic techniques to probe gene function and tissue interactions related to metabolism, and identify tractable targets for pharmacological intervention in type 2 diabetes. Over the past five years, the notable contributions of this grant to our knowledge of the insulin resistance syndrome have been: (i) a critical reassessment of the relative roles of insulin-dependent and -independent mechanisms of glucose disposal in metabolic homeostasis; (ii) the discovery of mechanisms by which non-canonical sites of insulin action, such as central nervous system (CNS) and endocrine pancreas, play an early and decisive role in the progression from insulin resistance to diabetes; and (iii) the notion that pancreatic β cells are an "insulin -sensitive" cell type. Building on these lessons, the Pl proposes studies of the integrated physiology of insulin action that will focus primarily on the contribution of CNS, liver and enteroendocrine system to the insulin-resistant state. The Pl presents data putatively identifying an "insulin-sensitive" neuron population, characterized by Glut4 expression; as well as a novel gut epithelial progenitor cell with the unique ability to give rise to bona fide insulin-secreting , "β-like" endocrine cells in vivo. Three aims are outlined: Aim 1 will tackle the role of insulin signaling in brain glucose metabolism, using a novel approach to identify Glut4- expressing neurons and characterize their contribution to systemic metabolism. Aim 2 will delve into the · pathophysiology of hepatic insulin resistance, and specifically into the identification of transcription factors that cause the paradoxical admixture of increased glucose production and triglyceride synthesis that characterizes the diabetic liver. Aim 3 will study the role of insulin signaling in a newly identified sub  population of gut epithelial progenitor cells that express the insulin-regulated transcription factor Foxo1 and show the surprising ability to be reprogrammed into "β-like" cells that secrete insulin in response to glucose The proposed body of work will advance our understanding of the insulin-resistant syndrome at the biochemical, genetic, and integrated physiological levels, with the ultimate goal of translating newly acquired information into innovative approaches to its treatment.', '[2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]', '["central nervous system", "insulin resistance", "role of insulin", "epithelial progenitor cells", "insulin action", "insulin resistant syndrome", "progenitor cells", "brain glucose metabolism", "insulin resistance syndrome", "type 2 diabetes", "hepatic insulin resistance", "insulin-resistant states", "unmet medical need", "pancreatic \u03b2-cells", "enteroendocrine system", "resistance syndrome", "non-canonical sites", "transcription factor FOXO1", "glucose disposal", "systemic metabolism", "diabetic liver", "pharmacological interventions", "mouse model", "protean syndrome", "glucose metabolism", "nervous system", "Aim 3", "endocrine pancreas", "medical need", "neuron populations", "gene function", "discovery of mechanisms", "endocrine cells", "glucose production", "\u03b2-cells", "Aim 2", "transcription factors", "syndrome", "metabolic homeostasis", "Aim 1", "triglyceride synthesis", "genetic techniques", "insulin", "GLUT4 expression", "tractable targets", "diabetes", "independent mechanisms", "complex biology", "cell types", "public health", "physiological levels", "liver",  ...
# ------
# FATAL:  codeProxyRefusedConnection: connection refused
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 3, in execute_command(query)
#       2 try:
# ----> 3     connection = psycopg2.connect(
#       4         "postgresql://selina04_mit_edu:n8fdpr78E1ooJXDjjXvUSA@livid-dibbler-6457.g8z.cockroachlabs.cloud:26257/livid-dibbler-6457.grants?sslmode=verify-full"
#       5     )
#       7     # Create a cursor and execute the insert statement
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: FATAL:  codeProxyRefusedConnection: connection refused
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 68
#      64 values_str = ', '.join(values)
#      66 insert_query = insert_query = f"INSERT INTO {cleaned_name} ({columns}) VALUES({values_str});"
# ---> 68 execute_command(insert_query)
#
# Cell In[12], line 3, in execute_command(query)
#       1 def execute_command(query):
#       2     try:
# ----> 3         connection = psycopg2.connect(
#       4             "postgresql://selina04_mit_edu:n8fdpr78E1ooJXDjjXvUSA@livid-dibbler-6457.g8z.cockroachlabs.cloud:26257/livid-dibbler-6457.grants?sslmode=verify-full"
#       5         )
#       7         # Create a cursor and execute the insert statement
#       8         cursor = connection.cursor()
#
# KeyboardInterrupt:
